# %% [markdown]
# Here we are importing numpy as np,pandas as pd ,matplotlib.pyplot as plot and seaborn as sb for data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sb

# %% [markdown]
# Now we are reading the datavalues in the file using read_csv with an encoding "utf-8" but we can also use "latin1" too
# if we use head for printing, the first five values in the dataset will be visible as default but we can also change the default
# number by entering the some value based on our interest i.e first 10 or 100 etc.
# We can also use tail for the values which will start from the end.

# %%
data = pd.read_csv('Diabetes.csv',encoding='utf-8')
data.head(10)

# %%
# WE ARE CREATING AN OUTPUT COLUMN AND GIVING A CONDITION BASED ON THE RANGE OF GLUCOSE VALUES
data['Output'] = data['Glucose'].apply(lambda y: 'diabetic' if y > 130 else 'prediabetic' if y > 90 and y<=130 else 'normal' if y>70 else 'diabetic')
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome       Output
# 0                     0.627   50        1     diabetic
# 1                     0.351   31        0       normal
# ...

# %%
# WE ARE CONVERTING THE RESULT VALUES FROM STRINGS TO INTEGERS IN THE OUTPUT COLUMN (NORMAL TO 0 etc.) 
data['Output'] = data['Output'].replace(['normal','prediabetic','diabetic'],[0,1,2])
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome  Output
# 0                     0.627   50        1       2
# 1                     0.351   31        0       0
# 2                     0.672   32        1       2
# ...

# %% [markdown]
# Now we are converting the above dataframe into a new csv file called "diabetes2.csv"

# %%
data.to_csv('diabetes2.csv',index=False, header=True)

# %% [markdown]
# Now we are printing data where we print a dataframe with glucose and output columns only from "diabetes2.csv"

# %%
data = data[['Glucose','Output']]
data.head(10)
# Out:
#    Glucose  Output
# 0      148       2
# 1       85       0
# 2      183       2
# 3       89       0
# 4      137       2
# 5      116       1
# 6       78       0
# 7      115       1
# 8      197       2
# 9      125       1

# %% [markdown]
# We are describing the data and printing it where glucose values are not equal to zero

# %%
data.describe()
# Out:
#           Glucose      Output
# count  768.000000  768.000000
# mean   120.894531    1.218750
# std     31.972618    0.655187
# min      0.000000    0.000000
# 25%     99.000000    1.000000
# 50%    117.000000    1.000000
# 75%    140.250000    2.000000
# max    199.000000    2.000000

# %% [markdown]
# Now we are creating another csv file called "diabetestest2.csv" and reading it

# %%
data.to_csv('diabetestest2.csv',index=False, header= True)
data.head(10)
# Out:
#    Glucose  Output
# 0      148       2
# 1       85       0
# 2      183       2
# 3       89       0
# 4      137       2
# 5      116       1
# 6       78       0
# 7      115       1
# 8      197       2
# 9      125       1

# %%
data = pd.read_csv('diabetes2.csv',encoding='latin1')
data.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome  Output
# 0                     0.627   50        1       2
# 1                     0.351   31        0       0
# 2                     0.672   32        1       2
# ...

# %%
# We are printing tail values(starting from the end) for data dataframe.
data = data[['Glucose','Insulin','Output']]
data.head(10)
# Out:
#    Glucose  Insulin  Output
# 0      148        0       2
# 1       85        0       0
# 2      183        0       2
# 3       89       94       0
# 4      137      168       2
# 5      116        0       1
# 6       78       88       0
# 7      115        0       1
# 8      197      543       2
# 9      125        0       1

# %% [markdown]
# Now we want to create a csv file where we give a condition (Glucose and Insulin values not equal to zero)

# %%
data = data[data['Insulin'] != 0]
data = data[data['Insulin'] != 0]

# %%
data.to_csv("diabetesNonzero.csv",index=False)
data
# Out:
#      Glucose  Insulin  Output
# 3         89       94       0
# 4        137      168       2
# 6         78       88       0
# 8        197      543       2
# 13       189      846       2
# ..       ...      ...     ...
# 753      181      510       2
# 755      128      110       1
# 760       88       16       0
# 763      101      180       1
# 765      121      112       1
#
# [394 rows x 3 columns]

# %%
# We are describing the data from diabetesnonzero csv file which prints statiscal data
data.describe()
# Out:
#           Glucose     Insulin      Output
# count  394.000000  394.000000  394.000000
# mean   122.304569  155.548223    1.210660
# std     31.396725  118.775855    0.664466
# min      0.000000   14.000000    0.000000
# 25%     99.000000   76.250000    1.000000
# 50%    119.000000  125.000000    1.000000
# 75%    143.000000  190.000000    2.000000
# max    198.000000  846.000000    2.000000

# %% [markdown]
# ##  Machine Learning part

# %% [markdown]
# sklearn also called scikit-learn is a ML Library which include tools like classification,regression,clustering etc. The ML learning methods like random forest, decision trees can be explained and analyzed using sklearn

# %% [markdown]
# We use model_selection when we want to split arrays into train and test subsets. Split ratio is used to split the labeled data into train and test data and split ratio = 0.2 refers to 80 percent training data and 20 percent testing data.
# We use train_test_split to evaluate performance of the machine learning algorithm.

# %%
# Here we are using model selection and importing train test split for evaluating the ML model
# shape explains the size of the dataset which is creating after splitting(rows,columns)

# %% [markdown]
# Here we are taking x_train as train columns other than Insulin in "data" and y_train as Insulin and for x_test we are taking test columns from columns other than Insulin and y_test for columns which are values of Insulin in test columns and we are printing shapes of each training and test dataset

# %%
from sklearn.model_selection import train_test_split as tts
splitRatio = 0.2
train, test = tts(data,test_size = splitRatio,random_state = 10)
x_train = train[[x for x in train.columns if x not in ['Insulin']]]
y_train = train[['Insulin']]
x_test = test[[x for x in test.columns if x not in ['Insulin']]]
y_test = test[['Insulin']]
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (315, 2)
# (315, 1)
# (79, 2)
# (79, 1)

# %%
# Now we are importing Linear Regression from linear model and accuracy score from sklearn_metrics

# %%
# We are using LinearRegression method to make a prediction
# We are fitting the training sets using Linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
models = LinearRegression()
models.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = models.predict(x_test)

# %%
new_df = pd.read_csv('diabetestest2.csv',encoding='latin1')
prediction = models.predict(new_df)
prediction
# The output are the predicted values in decimal(float)
# Out:
# array([[ 222.95457822],
#        [  69.17466757],
#        [ 300.52341163],
#        [  78.03967711],
#        [ 198.57580201],
#        [ 144.95649671],
#        [  53.66090089],
#        [ 142.74024432],
#        [ 331.550945  ],
#        [ 164.90276815],
#        [ 131.65898241],
#        [ 267.27962589],
#        [ 203.00830678],
#        [ 313.82092593],
#        [ 262.84712112],
#        [ 109.49645858],
#        [ 149.38900147],
#        [ 125.01022526],
#        [ 116.14521573],
#        [ 142.74024432],
#        [ 167.11902054],
#        [ 107.28020619],
#        [ 329.33469261],
#        [ 151.60525386],
#        [ 211.87331631],
#        [ 164.90276815],
#        [ 220.73832584],
#        [ 102.84770143],
#        [ 216.30582107],
#        [ 147.17274909],
#        [ 129.44273002],
#        [ 245.11710205],
#        [  75.82342472],
#        [  91.76643951],
#        [ 158.25401101],
#        [ 116.14521573],
#        [ 200.79205439],
#        [ 113.92896334],
# ...

# %%
prediction = prediction.astype(int)
prediction
# Now the prediction is converted to integer(rounded off)
# Out:
# array([[ 222],
#        [  69],
#        [ 300],
#        [  78],
#        [ 198],
#        [ 144],
#        [  53],
#        [ 142],
#        [ 331],
#        [ 164],
#        [ 131],
#        [ 267],
#        [ 203],
#        [ 313],
#        [ 262],
#        [ 109],
#        [ 149],
#        [ 125],
#        [ 116],
#        [ 142],
#        [ 167],
#        [ 107],
#        [ 329],
#        [ 151],
#        [ 211],
#        [ 164],
#        [ 220],
#        [ 102],
#        [ 216],
#        [ 147],
#        [ 129],
#        [ 245],
#        [  75],
#        [  91],
#        [ 158],
#        [ 116],
#        [ 200],
#        [ 113],
#        [  80],
#        [ 133],
#        [ 293],
#        [ 189],
#        [ 122],
#        [ 273],
#        [ 247],
#        [ 293],
#        [ 218],
#        [  38],
#        [ 116],
#        [ 120],
#        [ 116],
#        [ 111],
#        [  75],
#        [ 285],
#        [ 227],
#        [  42],
#        [ 309],
#        [ 109],
# ...

# %%
# We are converting the prediction from list into a dataframe and then to a csv giving the column name as Insulin(which is predicted)
out = pd.DataFrame(prediction,columns=['Insulin'])
out.to_csv('diabetespredresult.csv',index=False,header=True)
out
# Out:
#      Insulin
# 0        222
# 1         69
# 2        300
# 3         78
# 4        198
# ..       ...
# 763      111
# 764      158
# 765      156
# 766      167
# 767       93
#
# [768 rows x 1 columns]

# %%
# Here we are creating a two new variables df1 and df2 and reading it with predicted insulin and test2 results
df1 = pd.read_csv('diabetestest2.csv',encoding='latin1')
df2 = pd.read_csv('diabetespredresult.csv',encoding='latin1')

# %%
# we are appending df1 and df2 using concat function and printing the three columns given 
data = pd.concat([df1,df2],axis=1)
data = data[['Glucose','Insulin','Output']]

# %%
# we are reading diabetesnonzero csv" creating a list by concatenating df3 and data
df3 = pd.read_csv('diabetesNonzero.csv',encoding='latin1')
data
# Out:
#      Glucose  Insulin  Output
# 0        148      222       2
# 1         85       69       0
# 2        183      300       2
# 3         89       78       0
# 4        137      198       2
# ..       ...      ...     ...
# 763      101      111       1
# 764      122      158       1
# 765      121      156       1
# 766      126      167       1
# 767       93       93       1
#
# [768 rows x 3 columns]

# %%
list1 = [data,df3]
data  = pd.concat(list1)
data
# Out:
#      Glucose  Insulin  Output
# 0        148      222       2
# 1         85       69       0
# 2        183      300       2
# 3         89       78       0
# 4        137      198       2
# ..       ...      ...     ...
# 389      181      510       2
# 390      128      110       1
# 391       88       16       0
# 392      101      180       1
# 393      121      112       1
#
# [1162 rows x 3 columns]

# %%
data.to_csv('diabetesmerge.csv',index=False)
data = pd.read_csv('diabetesmerge.csv',encoding= 'latin1')
data
# Out:
#       Glucose  Insulin  Output
# 0         148      222       2
# 1          85       69       0
# 2         183      300       2
# 3          89       78       0
# 4         137      198       2
# ...       ...      ...     ...
# 1157      181      510       2
# 1158      128      110       1
# 1159       88       16       0
# 1160      101      180       1
# 1161      121      112       1
#
# [1162 rows x 3 columns]

# %% [markdown]
# We are importing model selection and train test split from sklearn and we are doing prediction for output as train and test columns same as we done for Insulin from train and test columns with split ratio of 0.2 means we are splitting the data into train:test = 8:2

# %%
from sklearn.model_selection import train_test_split as tts
splitratio = 0.2
train , test = tts(data,test_size = splitratio, random_state = 100)

# %%
x_train = train[[x for x in train.columns if x not in ['Output']]]
y_train = train[['Output']]
x_test = test[[x for x in test.columns if x not in ['Output']]]
y_test = test[['Output']]

# %% [markdown]
# We are importing below models from sklearn for various kinds of prediction to check which model provides more accuracy

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# We are checking accuracy score for each method for the above prediction just to get a proper idea and check which method is accurate for the above model

# %%
model = KNeighborsClassifier()
model.fit(x_train,y_train)
prediction = model.predict(x_test)
accuracy_score(y_test,prediction)
# Out:
# C:\Users\manoh\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.9828326180257511

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
prediction = model.predict(x_test)
accuracy_score(y_test,prediction)
# Out:
# C:\Users\manoh\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.9141630901287554

# %%
model = GaussianNB()
model.fit(x_train,y_train)
prediction = model.predict(x_test)
accuracy_score(y_test,prediction
# Out:
# C:\Users\manoh\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# 0.944206008583691

# %% [markdown]
# # GUI

# %% [markdown]
# Now we create a window for enter the input values of Glucose and Insulin using Tkinter. We create two labels and a button, give them measurement values and border lengths.

# %%
import tkinter as tk
import pandas as pd
def saveinfo():
    valor = int(E1.get())
    valor1 = int(E2.get())
    list = [[valor,valor1]]
    df = pd.DataFrame(list)
    df.to_csv("newdf.csv")
    top.destroy()

# %%
top = tk.Tk()
top.title("1st Input for Glucose and Insulin")
L1 = tk.Label(top,text = "Glucose Value :")
L1.place(x=12,y=12)
E1 = tk.Entry(top,bd=6)
E1.place(x=300,y=10)
L2=tk.Label(top,text="Insulin value :")
L2.place(x=12,y=60)
E2=tk.Entry(top,bd=5)
E2.place(x=300,y=50)
b=tk.Button(top,text="Submit",command=saveinfo)
b.place(x=12,y=100)
top.geometry('600x600')
top.mainloop()

# %% [markdown]
# We are creating a new variable called new_df which is newdf file consisting of glucose and insulin and glucose values not equal to zero which we created in tkinter from a list.
#
# Now we do the prediction using Logistic Regression

# %%
new_df=pd.read_csv('newdf.csv',encoding='latin1',names=["Glucose","Insulin"])
new_df=new_df[new_df["Glucose"]!=0]
prediction = model.predict(new_df)
model1=LogisticRegression()
model1.fit(X_train,y_train)
prediction1 = model1.predict(new_df)

# %%
model2 = GaussianNB()
model2.fit(x_train,y_train)
prediction2 = model2.predict(new_df)

# %% [markdown]
# We are creating three variables for three models which gives the probability of each model. "predict_proba" provides the probability of a model

# %%
new = model.predict_proba(new_df)[:]
new1 = model1.predict_proba(new_df)[:]
new2 = model2.predict_proba(new_df)[:]
message = ""

# %% [markdown]
# Now in the below two cells We are creating a message based on the prediction by K-neighbour classifier where we produce a message and based on the probability we will explain the diabetic status

# %%
if prediction == 0:
    message = "Normal level"
elif prediction == 1:
    message = "Pre-diabetic"
elif prediction == 2:
    message = "Diabetic"

# %%
proba = int(((new[:,2])) * 100)
result1 = "Your K-neigbour Diabetic Status is " + message + ". You have " +format(proba)+ " % chance of being Diabetic ."

# %% [markdown]
# Now in the below two cells We are creating a message based on the prediction by Logistic Regression where we produce a message and based on the probability we will explain the diabetic status

# %%
if prediction1 == 0:
    message = 'Normal'
elif prediction1 == 1:
    message = "Pre-diabetic"
elif prediction1 == 2:
    message = "Diabetic"

# %%
proba1 = int(((new1[:,2])) * 100)
result2 = "Your Diabetic Status based on Logistic Regression is " + message + ". You have " +format(proba1)+ " % chance of being Diabetic ."

# %% [markdown]
# Now in the below two cells We are creating a message based on the prediction by Gaussian NB(Naive Bayes) where we produce a message and based on the probability we will explain the diabetic status

# %%
if prediction2 == 0:
    message = 'Normal'
elif prediction2 == 1:
    message = "Pre-diabetic"
elif prediction2 == 2:
    message = "Diabetic"

# %%
proba2 = int(((new2[:,2])) * 100)
result3 = "Your Diabetic Status based on Naive Bayes is " + message + ". You have " +format(proba2)+ " % chance of being Diabetic ."

# %% [markdown]
# We are using train_test_split and splitting data into train and test based on columns other than "Output" and fitting models using the below three methods

# %%
from sklearn.model_selection import train_test_split
splitRatio = 0.2
train, test = train_test_split(data,test_size = SplitRatio, random_state = 120)
x_train = train[[x for x in train.columns if x not in ["Output"]]]
y_train = train[['Output']]
x_test = test[[x for x in test.columns if x not in ['Output']]]
y_test = test[['Output']]

# %%
model = KNeighboursClassifier()
model.fit(x_train,y_train)

# %%
model1 = LogisticRegression()
model1.fit(x_train,y_train)

# %%
model2 = GaussianNB()
model2.fit(x_train,y_train)

# %%
prediction = model.predict(x_test)

# %% [markdown]
# Now we are creating a window using tkinter for printing accuracy scores(train and test accuracies) for each ML method we made the prediction on.

# %%
res.title("OUTPUT")
var=tk.StringVar()
var1=tk.StringVar()
var2=tk.StringVar()
var3=tk.StringVar()
var4=tk.StringVar()
var5=tk.StringVar()
var6=tk.StringVar()
var7=tk.StringVar()
var8=tk.StringVar()
value1="K-Neighbor Train accuracy is : "+ str(model.score(X_train, y_train))
value2="K-Neighbor Test accuracy is : "+ str(model.score(X_test, y_test))
value3="Logistic Regression Train accuracy is : "+ str(model1.score(X_train, y_train))
value4="Logistic Regression Test accuracy is : "+ str(model1.score(X_test, y_test))
value5="Gaussian NB Train accuracy is : "+ str(model2.score(X_train, y_train))
value6="Gaussian NB Test accuracy is : "+ str(model2.score(X_test, y_test))

# %%
lab=tk.Label(res,textvariable=var1)
lab.place(x=10,y=10)
lab.config(font=("Courier", 14))
lab1=tk.Label(res,textvariable=var2)
lab1.place(x=10,y=70)
lab1.config(font=("Courier", 14))
lab2=tk.Label(res,textvariable=var3)
lab2.place(x=10,y=140)
lab2.config(font=("Courier", 14))
lab3=tk.Label(res,textvariable=var4)
lab3.place(x=10,y=210)
lab3.config(font=("Courier", 14))
lab4=tk.Label(res,textvariable=var5)
lab4.place(x=10,y=280)
lab4.config(font=("Courier", 14))
lab5=tk.Label(res,textvariable=var6)
lab5.place(x=10,y=350)
lab5.config(font=("Courier", 14))
lab6=tk.Label(res,textvariable=var)
lab6.place(x=10,y=420)
lab6.config(font=("Forte", 14))
lab7=tk.Label(res,textvariable=var7)
lab7.place(x=10,y=480)
lab7.config(font=("Forte", 14))
lab8=tk.Label(res,textvariable=var8)
lab8.place(x=10,y=520)
lab8.config(font=("Forte", 14))
var.set(result1)
var1.set(value1)
var2.set(value2)
var3.set(value3)
var4.set(value4)
var5.set(value5)
var6.set(value6)
var7.set(result2)
var8.set(result3)
res.geometry('1000x500')
res.mainloop()

# %% [markdown]
# Now we are plotting the accuracy scores by converting them into a list and plot using seaborn

# %%
list1=[model.score(X_test, y_test),model1.score(X_test, y_test),model2.score(X_test, y_test)]
plot=pd.DataFrame(list1,columns=["TestValues"])
sb.set_style('whitegrid')
sb.distplot(plot["TestValues"],kde=False,color='darkred',bins=30)

# %%
list3=[(Proba),(Proba1),(Proba2)]
plot3=pd.DataFrame(list3,columns=["TestValues"])
sb.set_style('whitegrid')
sb.distplot(plot3["TestValues"],kde=False,color='darkred',bins=30)

# %% [markdown]
# Now we import os and remove newdf.csv which we imported in tkinter

# %%
import os 
os.remove("newdf.csv")
